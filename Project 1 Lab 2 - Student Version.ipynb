# %% [markdown]
# ## Organizing Data
# Performing initial exploratory analysis of big data sets is becoming a critical skill for civil and environmental engineers.  Data sets are getting bigger over time and that makes it more difficult to determine how the data impacts our designs and decision making as an engineer.  If we can quickly explore the data to determine if it is useful to us, this will help us quickly and effectively tell our clients what they want to know.  This lab is dedicated to teaching you how to organize data, including filtering, grouping, aggregating and categorizing.  Let's get started!

# %% [markdown]
# #### Start every notebook the same:
# 1. Check your working directory has the data you need
# 2. Check you have all the relevant packages loaded
# 3. Load any relevant data sets

# %%
### Install packages
import pandas as pd

### Load data
air_data = pd.read_csv('AirQuality_Daily_StudentVersion (1).csv')

# %% [markdown]
# We may also want to make sure that the new data set we imported is a dataframe. Dataframes are a type of data structure in Python where each column is interpreted as a different variable that can then be manipulated. If we want to coerce a data set into a data frame, we can use the following syntax. Note that this syntax overwrites the `air_data` we created above! Also, the `pd.` before the function tells Python that this function comes from the pandas package.

# %%
air_data = pd.DataFrame(air_data)

# %% [markdown]
# Next, we can use the print function to examine what types of data are present in our CSV. This gives us a chance to examine what types of data are present and what variables we will be able to manipulate.

# %%
#print(air_data)
print(air_data.columns)
print(air_data.head(5))
print(air_data.tail(5))
# Out:
# Index(['date', 'monitor_index', 'humidity', 'pressure', 'temperature', 'voc',
#        'analog_input', 'pm2.5_alt', 'pm1.0_atm', 'pm2.5_atm', 'pm10.0_atm',
#        'sensor.latitude', 'sensor.longitude', 'sensor.altitude',
#        'sensor.name'],
#       dtype='object')
#        date  monitor_index   humidity    pressure  temperature         voc  \
# 0  02/23/24         195089  14.377667  912.884333    62.266667   51.998667
# 1  02/23/24         195365  12.223600  926.403000    71.193400   64.920800
# 2  02/23/24         195541  20.095750  905.670750    61.008250   68.307000
# 3  02/24/24         195089  25.368000  911.708833    51.462458   91.176750
# 4  02/24/24         195365  23.703083  925.282125    56.818208  107.863708
#
#    analog_input  pm2.5_alt  pm1.0_atm  pm2.5_atm  pm10.0_atm  sensor.latitude  \
# 0      0.051333     0.1000   0.000000   0.002500    0.039667        40.050922
# 1      0.000000     0.1800   0.004800   0.020000    0.176000        40.200330
# 2      0.020000     0.1625   0.004125   0.014812    0.063937        41.128284
# 3      0.052667     0.4375   0.099542   0.170667    0.355208        40.050922
# 4      0.000000     0.4750   0.099208   0.231687    0.548583        40.200330
#
#    sensor.longitude  sensor.altitude       sensor.name
# 0       -101.533570             3005  Swnphd-Benklemen
# 1       -100.639885             2576     Swnphd-mccook
# 2       -101.720220             3220   Swnphd-ogallala
# 3       -101.533570             3005  Swnphd-Benklemen
# 4       -100.639885             2576     Swnphd-mccook
#           date  monitor_index   humidity    pressure  temperature         voc  \
# 8296  03/24/25         195373  23.636208  915.998292    61.489083  421.493750
# 8297  03/24/25         195379  28.043545  954.294546    66.009182  301.074800
# 8298  03/24/25         195383  31.451375  936.556583    55.752792  353.478000
# 8299  03/24/25         195385        NaN         NaN          NaN         NaN
# 8300  03/24/25         195541  20.494500  901.484750    61.222167  485.556417
#
#       analog_input  pm2.5_alt  pm1.0_atm  pm2.5_atm  pm10.0_atm  \
# 8296          0.02   0.762500   0.486583   0.830021    1.416125
# 8297          0.00   0.800000   5.625545   5.873364    6.056773
# 8298          0.05   0.575000   0.267500   0.478375    0.818146
# 8299          0.01   0.970833   0.739500   1.088604    1.340563
# 8300          0.02   0.554167   0.132083   0.340417    0.737375
#
#       sensor.latitude  sensor.longitude  sensor.altitude  \
# 8296        41.148170       -100.761800             2800
# 8297        40.877007        -97.579445             1639
# 8298        41.779380        -99.138040             2174
# 8299        40.019714        -98.071840             1597
# 8300        41.128284       -101.720220             3220
#
#                                             sensor.name
# 8296                                WCDHD City Building
# 8297                                           FCHD-YPS
# 8298                Loup Basin Public Health Department
# 8299  South Heartland District Health Dept. Superior...
# 8300                                    Swnphd-ogallala

# %% [markdown]
# We have many different way of checking our data is properly loaded.  It's always good practice to try at least one method before starting out analysis.  Here are the methods we can use:
# 1. Use `print` to show the entire data set
# 2. Append `.columns` to the end of a data set to look at the column names
# 3. Append `.head()` to view the top rows of the dataset (default is 5)
# 4. Append `.tail()` to view the bottom rows of the dataset (default is 5)

# %% [markdown]
# ## Summarizing Data

# %% [markdown]
# Next, let's look at how to group data. This is an important skill when you want to examine data in a final table that summarizes a statistic or characterisitic of your data.
#
# 1.) Append `.groupby()` to the end of a variable and then use square brackets [] and list the columns you want to group by
#
# 2.) Then, add `.size()` to the end of the statement to show the number of observations in each group
#
# 3.) Use `print` to show this new dataframe

# %%
### Use this space for grouping data
sensor_counts = air_data.groupby("sensor.name").size()
print(sensor_counts)
# Out:
# sensor.name
# #16 - Richardson County Courthouse                              318
# #17 - Otoe County                                               302
# #18 - Southeast District Health Department- Tecumseh            183
# Ainsworth Public School #9                                      368
# Broken Bow                                                      368
# Buffalo County TRPHD #26                                        359
# ELVPHD Norfolk HD 4                                             171
# ELVPHD Tekamah HD 3                                             202
# ELVPHD Wisner HD 5                                              357
# FCHD-YPS                                                        365
# Laurel High School                                              172
# Loup Basin Public Health Department                             389
# Lower Niobrara NRD Butte 10                                     371
# NCDHD O'Neill #11                                               226
# PHS Fairbury JCHL 13                                            348
# SWNPHD-Imerial                                                  284
# South Heartland District Health Dept. Hastings office           377
# South Heartland District Health Dept. Superior City Building    286
# Swnphd-Benklemen                                                388
# Swnphd-mccook                                                   390
# Swnphd-ogallala                                                 376
# TRPHD Dawson Co. Courthouse 25                                  387
# TRPHD Harlan Co. Courthouse 24                                  367
# Three Rivers Public Health Department                           377
# WCDHD Arthur High School 28                                     320
# WCDHD City Building                                             103
# WCDHD Thedford Library 29                                       147
# dtype: int64

# %% [markdown]
# Now, we may want to use the data we just generated in future analyses. Therefore, we need to save that data to a variable. We will add `.reset_index(name = '')` to the end of the previous code and put the name of the new column within the quote marks. We will assign this new dataframe to a dataframe called `summary` and then print the results.
#
# This code will give us the number of rows associated with the `sensor.name` in the Air Purple data set

# %%
## Add the index here
pm_table = (air_data.groupby("sensor.name")[["pm2.5_atm", "pm10.0_atm"]].mean().reset_index())
print(pm_table)
# Out:
#                                           sensor.name   pm2.5_atm  pm10.0_atm
# 0                  #16 - Richardson County Courthouse  700.127342  701.632446
# 1                                   #17 - Otoe County    9.755345   11.671141
# 2   #18 - Southeast District Health Department- Te...  613.175352  614.227248
# 3                          Ainsworth Public School #9   10.697058   12.390708
# 4                                          Broken Bow  928.710593  929.678512
# 5                            Buffalo County TRPHD #26    8.479442    9.596038
# 6                                 ELVPHD Norfolk HD 4   13.369492   15.969341
# 7                                 ELVPHD Tekamah HD 3    9.482822   10.683828
# 8                                  ELVPHD Wisner HD 5   11.154420   14.462116
# 9                                            FCHD-YPS    9.167842   11.138241
# 10                                 Laurel High School    8.635639   10.254001
# 11                Loup Basin Public Health Department    8.561095   10.454420
# 12                        Lower Niobrara NRD Butte 10    8.041274    9.365581
# 13                                  NCDHD O'Neill #11  164.495078  166.132578
# 14                               PHS Fairbury JCHL 13    9.405360   11.132398
# 15                                     SWNPHD-Imerial    6.329091    7.281414
# 16  South Heartland District Health Dept. Hastings...    8.915233    9.852555
# 17  South Heartland District Health Dept. Superior...    8.851045    9.851113
# 18                                   Swnphd-Benklemen    7.501374    9.041440
# 19                                      Swnphd-mccook  123.011622  124.227336
# 20                                    Swnphd-ogallala   10.396579   11.347889
# 21                     TRPHD Dawson Co. Courthouse 25   18.080629   19.548148
# 22                     TRPHD Harlan Co. Courthouse 24    7.927510    8.944145
# 23              Three Rivers Public Health Department    9.601760   11.226492
# 24                        WCDHD Arthur High School 28    6.658474    7.712941
# 25                                WCDHD City Building    3.971512    4.817597
# 26                          WCDHD Thedford Library 29    6.219710    7.509269

# %% [markdown]
# What about grouping by multiple groups?  That is 100% doable if each column name is correctly named and called within [ ]  to index each column name.  Let's try this below.

# %%
## Group with multiple names
pm_table = (air_data.groupby("sensor.name")[["pm2.5_atm", "pm10.0_atm"]].mean().reset_index())
print(pm_table)
# Out:
#                                           sensor.name   pm2.5_atm  pm10.0_atm
# 0                  #16 - Richardson County Courthouse  700.127342  701.632446
# 1                                   #17 - Otoe County    9.755345   11.671141
# 2   #18 - Southeast District Health Department- Te...  613.175352  614.227248
# 3                          Ainsworth Public School #9   10.697058   12.390708
# 4                                          Broken Bow  928.710593  929.678512
# 5                            Buffalo County TRPHD #26    8.479442    9.596038
# 6                                 ELVPHD Norfolk HD 4   13.369492   15.969341
# 7                                 ELVPHD Tekamah HD 3    9.482822   10.683828
# 8                                  ELVPHD Wisner HD 5   11.154420   14.462116
# 9                                            FCHD-YPS    9.167842   11.138241
# 10                                 Laurel High School    8.635639   10.254001
# 11                Loup Basin Public Health Department    8.561095   10.454420
# 12                        Lower Niobrara NRD Butte 10    8.041274    9.365581
# 13                                  NCDHD O'Neill #11  164.495078  166.132578
# 14                               PHS Fairbury JCHL 13    9.405360   11.132398
# 15                                     SWNPHD-Imerial    6.329091    7.281414
# 16  South Heartland District Health Dept. Hastings...    8.915233    9.852555
# 17  South Heartland District Health Dept. Superior...    8.851045    9.851113
# 18                                   Swnphd-Benklemen    7.501374    9.041440
# 19                                      Swnphd-mccook  123.011622  124.227336
# 20                                    Swnphd-ogallala   10.396579   11.347889
# 21                     TRPHD Dawson Co. Courthouse 25   18.080629   19.548148
# 22                     TRPHD Harlan Co. Courthouse 24    7.927510    8.944145
# 23              Three Rivers Public Health Department    9.601760   11.226492
# 24                        WCDHD Arthur High School 28    6.658474    7.712941
# 25                                WCDHD City Building    3.971512    4.817597
# 26                          WCDHD Thedford Library 29    6.219710    7.509269

# %% [markdown]
# ### Lab Activity #1: Grouping
# In the code block below, show you can group your original air_data by `monitor_index` and call this new dataframe `monitor_grouped` and how many observations there are in each group.

# %%
### Enter your response to Lab Activity #1 in this cell
monitor_grouped = air_data.groupby("monitor_index").size()
print(monitor_grouped)
# Out:
# monitor_index
# 194969    284
# 195089    388
# 195091    357
# 195103    172
# 195315    367
# 195317    318
# 195319    377
# 195327    202
# 195329    371
# 195331    147
# 195333    387
# 195339    302
# 195341    348
# 195343    171
# 195345    359
# 195347    368
# 195349    183
# 195355    320
# 195361    226
# 195362    368
# 195365    390
# 195367    377
# 195373    103
# 195379    365
# 195383    389
# 195385    286
# 195541    376
# dtype: int64

# %% [markdown]
# The code above only summarizes the total number of samples.  What if we want to know some more in depth statistics about this data?
#
# The function `.agg()` is a pandas function that aggregates data.  Note that because it is a pandas function, `.agg()` will only work if you have imported the correct packages!
#
# `.agg()` can take arguments such as max, min, mean and median.  In order for this function to work, you need to tell `.agg()` which summary statistic you want (for example `max()`) and then tell the statistic what to take the statistic of and what you want that new data column to be called.  For example, if we want to take the max() of the column "pm2.5_atm" and name this new data column "maximum", our code would look like this:
# `.agg(max('violations', 'maximum')`
#
# Try this out using your summary data, group by contaminant and assign this new summary statistic data to a data frame called `stat_summary`and print this new dataframe to the console.

# %%
### Create your stat_summary here
stat_summary = air_data.groupby(['sensor.name']).agg(max=('pm2.5_atm', 'max'),
                                                     min=('pm2.5_atm', 'min'),
                                                     mean=('pm2.5_atm', 'mean'),
                                                     median=('pm2.5_atm', 'median'))
stat_summary
# Out:
#                                                             max       min  \
# sensor.name
# #16 - Richardson County Courthouse                  3782.823313  0.243729
# #17 - Otoe County                                     37.250062  0.000000
# #18 - Southeast District Health Department- Tec...  2987.467563  0.140708
# Ainsworth Public School #9                            43.320062  0.089375
# Broken Bow                                          3205.868854  0.019187
# Buffalo County TRPHD #26                              42.225333  0.005896
# ELVPHD Norfolk HD 4                                   79.972917  0.307896
# ELVPHD Tekamah HD 3                                   45.881250  0.104938
# ELVPHD Wisner HD 5                                    51.984812  0.154271
# FCHD-YPS                                             363.201104  0.013125
# Laurel High School                                    38.736938  0.080250
# Loup Basin Public Health Department                  230.482438  0.034708
# Lower Niobrara NRD Butte 10                           45.030938  0.082437
# NCDHD O'Neill #11                                   2078.873729  0.136958
# PHS Fairbury JCHL 13                                  52.773958  0.045604
# SWNPHD-Imerial                                        49.004625  0.001313
# South Heartland District Health Dept. Hastings ...    47.330646  0.063292
# South Heartland District Health Dept. Superior ...    40.539417  0.043271
# Swnphd-Benklemen                                     188.156771  0.002500
# Swnphd-mccook                                       3053.114292  0.020000
# Swnphd-ogallala                                     1320.155667  0.004188
# TRPHD Dawson Co. Courthouse 25                      2363.017646  0.033188
# TRPHD Harlan Co. Courthouse 24                        42.725625  0.009542
# Three Rivers Public Health Department                 51.491208  0.171833
# WCDHD Arthur High School 28                           46.354292  0.024729
# WCDHD City Building                                   32.589521  0.031354
# WCDHD Thedford Library 29                             36.138729  0.028396
#
#                                                           mean     median
# sensor.name
# #16 - Richardson County Courthouse                  700.127342  11.977344
# #17 - Otoe County                                     9.755345   7.687563
# #18 - Southeast District Health Department- Tec...  613.175352  10.322875
# Ainsworth Public School #9                           10.697058   8.389740
# Broken Bow                                          928.710593  36.050240
# Buffalo County TRPHD #26                              8.479442   5.698500
# ELVPHD Norfolk HD 4                                  13.369492   9.706229
# ELVPHD Tekamah HD 3                                   9.482822   6.418302
# ELVPHD Wisner HD 5                                   11.154420   8.464583
# FCHD-YPS                                              9.167842   5.838188
# Laurel High School                                    8.635639   5.312083
# Loup Basin Public Health Department                   8.561095   5.213938
# Lower Niobrara NRD Butte 10                           8.041274   5.691250
# NCDHD O'Neill #11                                   164.495078   7.251208
# PHS Fairbury JCHL 13                                  9.405360   6.714948
# SWNPHD-Imerial                                        6.329091   3.338094
# South Heartland District Health Dept. Hastings ...    8.915233   6.251146
# South Heartland District Health Dept. Superior ...    8.851045   6.844604
# Swnphd-Benklemen                                      7.501374   4.215375
# Swnphd-mccook                                       123.011622   4.582281
# Swnphd-ogallala                                      10.396579   3.518510
# TRPHD Dawson Co. Courthouse 25                       18.080629   5.776813
# TRPHD Harlan Co. Courthouse 24                        7.927510   5.329063
# Three Rivers Public Health Department                 9.601760   6.860375
# WCDHD Arthur High School 28                           6.658474   3.921687
# WCDHD City Building                                   3.971512   2.830708
# WCDHD Thedford Library 29                             6.219710   3.288542

# %% [markdown]
# What if we wanted to group by a different column? How would the code look different if you wanted to look at the altitude versus the sensor name?

# %%
## Try grouping by a different column here
stat_summary = air_data.groupby(['sensor.name']).agg(max=('sensor.altitude', 'max'),
                                                     min=('sensor.altitude', 'min'),
                                                     mean=('sensor.altitude', 'mean'),
                                                     median=('sensor.altitude', 'median'))

# %% [markdown]
# ### Lab Activity 2: Aggregating
# In the code block below, show you can create a statistical summary (including the mean, max, min, and median) of the concentration of VOCs, grouped by `sensor.name`.

# %%
####Enter your response to Lab Activity #2 in this cell

stat_summary = air_data.groupby(['sensor.name']).agg(max=('pm2.5_atm', 'max'),
                                                     min=('pm2.5_atm', 'min'),
                                                     mean=('pm2.5_atm', 'mean'),
                                                     median=('pm2.5_atm', 'median'))

# %% [markdown]
# ### Filtering
# Next, let's examine how to filter data so that we only keep the observations relevant to our intended analysis.
#
# First, we can filter our data by using indices and AND (&) or OR   (|) operators. Let's try filtering for only the `sensor.name` "Swnphd-mccook". The variable we want to index to filter is the 'sensor.name' column name and the condition we want is only the columns with the string 'Swnphd-mccook'. Therefore, we can write:

# %%
## Indexing filter method
mccook_data = air_data[air_data["sensor.name"] == "Swnphd-mccook"]
print(mccook_data)
# Out:
#           date  monitor_index   humidity    pressure  temperature         voc  \
# 1     02/23/24         195365  12.223600  926.403000    71.193400   64.920800
# 4     02/24/24         195365  23.703083  925.282125    56.818208  107.863708
# 7     02/25/24         195365  17.341708  919.602625    61.311000  104.390083
# 10    02/26/24         195365  14.355708  914.554458    65.521375   81.122042
# 13    02/27/24         195365  28.790542  910.613708    48.362458   78.246542
# ...        ...            ...        ...         ...          ...         ...
# 8211  03/20/25         195365   0.000000  917.259000    41.000000    0.000000
# 8232  03/21/25         195365   0.000000  917.259000    41.000000    0.000000
# 8253  03/22/25         195365   0.000000  917.259000    41.000000    0.000000
# 8274  03/23/25         195365   0.000000  917.259000    41.000000    0.000000
# 8295  03/24/25         195365   0.000000  917.259000    41.000000    0.000000
#
#       analog_input  pm2.5_alt    pm1.0_atm    pm2.5_atm   pm10.0_atm  \
# 1              0.0   0.180000     0.004800     0.020000     0.176000
# 4              0.0   0.475000     0.099208     0.231687     0.548583
# 7              0.0   0.941667     0.543604     0.907917     1.609354
# 10             0.0   1.037500     0.593521     1.106292     2.125104
# 13             0.0   1.250000     0.848125     1.547187     2.770917
# ...            ...        ...          ...          ...          ...
# 8211           0.0   2.354167  1502.028354  1502.730792  1503.233313
# 8232           0.0   0.770833   857.841917   858.072271   858.946250
# 8253           0.0   1.020833   924.773688   925.109229   926.086146
# 8274           0.0   0.316667   981.894229   981.919875   982.185500
# 8295           0.0   0.475000   563.214896   563.337313   564.363833
#
#       sensor.latitude  sensor.longitude  sensor.altitude    sensor.name
# 1            40.20033       -100.639885             2576  Swnphd-mccook
# 4            40.20033       -100.639885             2576  Swnphd-mccook
# 7            40.20033       -100.639885             2576  Swnphd-mccook
# 10           40.20033       -100.639885             2576  Swnphd-mccook
# 13           40.20033       -100.639885             2576  Swnphd-mccook
# ...               ...               ...              ...            ...
# 8211         40.20033       -100.639885             2576  Swnphd-mccook
# 8232         40.20033       -100.639885             2576  Swnphd-mccook
# 8253         40.20033       -100.639885             2576  Swnphd-mccook
# 8274         40.20033       -100.639885             2576  Swnphd-mccook
# 8295         40.20033       -100.639885             2576  Swnphd-mccook
#
# [390 rows x 15 columns]

# %% [markdown]
# Notice that the variable name (sensor.name) and the string ('Swnphd-mccook') must both be in quotes.  We also use a double equals sign (==) when we are asking Python to find a specific case within a column.  A single equal sign (=) is used to assign new variables.
#
# Also notice that we can print only the `sensor.name` column by appending it to the dataframe as a way to check that we have properly filtered our data.
#
# There are other methods that can be used to filter in Python.  For example, the function `df.query()` can be used to examine the McCook sensors:

# %%
## Query filter method
mccook_data = air_data.query("`sensor.name` == 'Swnphd-mccook'")
print(mccook_data)
# Out:
#           date  monitor_index   humidity    pressure  temperature         voc  \
# 1     02/23/24         195365  12.223600  926.403000    71.193400   64.920800
# 4     02/24/24         195365  23.703083  925.282125    56.818208  107.863708
# 7     02/25/24         195365  17.341708  919.602625    61.311000  104.390083
# 10    02/26/24         195365  14.355708  914.554458    65.521375   81.122042
# 13    02/27/24         195365  28.790542  910.613708    48.362458   78.246542
# ...        ...            ...        ...         ...          ...         ...
# 8211  03/20/25         195365   0.000000  917.259000    41.000000    0.000000
# 8232  03/21/25         195365   0.000000  917.259000    41.000000    0.000000
# 8253  03/22/25         195365   0.000000  917.259000    41.000000    0.000000
# 8274  03/23/25         195365   0.000000  917.259000    41.000000    0.000000
# 8295  03/24/25         195365   0.000000  917.259000    41.000000    0.000000
#
#       analog_input  pm2.5_alt    pm1.0_atm    pm2.5_atm   pm10.0_atm  \
# 1              0.0   0.180000     0.004800     0.020000     0.176000
# 4              0.0   0.475000     0.099208     0.231687     0.548583
# 7              0.0   0.941667     0.543604     0.907917     1.609354
# 10             0.0   1.037500     0.593521     1.106292     2.125104
# 13             0.0   1.250000     0.848125     1.547187     2.770917
# ...            ...        ...          ...          ...          ...
# 8211           0.0   2.354167  1502.028354  1502.730792  1503.233313
# 8232           0.0   0.770833   857.841917   858.072271   858.946250
# 8253           0.0   1.020833   924.773688   925.109229   926.086146
# 8274           0.0   0.316667   981.894229   981.919875   982.185500
# 8295           0.0   0.475000   563.214896   563.337313   564.363833
#
#       sensor.latitude  sensor.longitude  sensor.altitude    sensor.name
# 1            40.20033       -100.639885             2576  Swnphd-mccook
# 4            40.20033       -100.639885             2576  Swnphd-mccook
# 7            40.20033       -100.639885             2576  Swnphd-mccook
# 10           40.20033       -100.639885             2576  Swnphd-mccook
# 13           40.20033       -100.639885             2576  Swnphd-mccook
# ...               ...               ...              ...            ...
# 8211         40.20033       -100.639885             2576  Swnphd-mccook
# 8232         40.20033       -100.639885             2576  Swnphd-mccook
# 8253         40.20033       -100.639885             2576  Swnphd-mccook
# 8274         40.20033       -100.639885             2576  Swnphd-mccook
# 8295         40.20033       -100.639885             2576  Swnphd-mccook
#
# [390 rows x 15 columns]

# %% [markdown]
# Now, what if we want to apply more than one filter?
#
# What if we want only the McCook location AND systems with an altitude greater than 2000 ft? We can use the & sign to represent AND in Python. this means that if we want 'sensor.name' == "Swnphd-mccook" AND also want 'sensor.altitude' => 2000, then we would need to write the following:

# %%
## Multiple filters here
mccook_high_alt = air_data[
    (air_data["sensor.name"] == "Swnphd-mccook") &
    (air_data["sensor.altitude"] > 2000)]
print(mccook_high_alt)
# Out:
#           date  monitor_index   humidity    pressure  temperature         voc  \
# 1     02/23/24         195365  12.223600  926.403000    71.193400   64.920800
# 4     02/24/24         195365  23.703083  925.282125    56.818208  107.863708
# 7     02/25/24         195365  17.341708  919.602625    61.311000  104.390083
# 10    02/26/24         195365  14.355708  914.554458    65.521375   81.122042
# 13    02/27/24         195365  28.790542  910.613708    48.362458   78.246542
# ...        ...            ...        ...         ...          ...         ...
# 8211  03/20/25         195365   0.000000  917.259000    41.000000    0.000000
# 8232  03/21/25         195365   0.000000  917.259000    41.000000    0.000000
# 8253  03/22/25         195365   0.000000  917.259000    41.000000    0.000000
# 8274  03/23/25         195365   0.000000  917.259000    41.000000    0.000000
# 8295  03/24/25         195365   0.000000  917.259000    41.000000    0.000000
#
#       analog_input  pm2.5_alt    pm1.0_atm    pm2.5_atm   pm10.0_atm  \
# 1              0.0   0.180000     0.004800     0.020000     0.176000
# 4              0.0   0.475000     0.099208     0.231687     0.548583
# 7              0.0   0.941667     0.543604     0.907917     1.609354
# 10             0.0   1.037500     0.593521     1.106292     2.125104
# 13             0.0   1.250000     0.848125     1.547187     2.770917
# ...            ...        ...          ...          ...          ...
# 8211           0.0   2.354167  1502.028354  1502.730792  1503.233313
# 8232           0.0   0.770833   857.841917   858.072271   858.946250
# 8253           0.0   1.020833   924.773688   925.109229   926.086146
# 8274           0.0   0.316667   981.894229   981.919875   982.185500
# 8295           0.0   0.475000   563.214896   563.337313   564.363833
#
#       sensor.latitude  sensor.longitude  sensor.altitude    sensor.name
# 1            40.20033       -100.639885             2576  Swnphd-mccook
# 4            40.20033       -100.639885             2576  Swnphd-mccook
# 7            40.20033       -100.639885             2576  Swnphd-mccook
# 10           40.20033       -100.639885             2576  Swnphd-mccook
# 13           40.20033       -100.639885             2576  Swnphd-mccook
# ...               ...               ...              ...            ...
# 8211         40.20033       -100.639885             2576  Swnphd-mccook
# 8232         40.20033       -100.639885             2576  Swnphd-mccook
# 8253         40.20033       -100.639885             2576  Swnphd-mccook
# 8274         40.20033       -100.639885             2576  Swnphd-mccook
# 8295         40.20033       -100.639885             2576  Swnphd-mccook
#
# [390 rows x 15 columns]

# %% [markdown]
# ### Lab Activity #3: Data Types
# Take note!  Python did a good job here and read in the `sensor.altitude` as a numerical value so we could perform the filter.  What would we need to do if Python was not recognizing the `sensor.altitude` as a number?  Enter your response in the cell below:

# %% [markdown]
# Student response to Lab Activity #3:

# %% [markdown]
# ## Putting Groups, Filters and Aggregate together
# Let's combine what we've just learned.
#
# Our client wants all the results grouped by `sensor.name`.  They also want summary statistics for `pm10.0_atm`, `pm2.5_atm` and `voc`, including `max`, `min`, `mean` and `median`.  For practice, let's also say that we only want temperatures above 50 F.  How would we put all of these elements together?

# %%
### Put it all together!
stat_summary = (air_data.loc[air_data["temperature"] > 50].groupby("sensor.name").agg(pm10_max = ("pm10.0_atm", "max"),
                                                                                      pm10_min = ("pm10.0_atm", "min"),
                                                                                      pm10_mean = ("pm10.0_atm", "mean"),
                                                                                      pm10_median = ("pm10.0_atm", "median"),
                                                                                      
                                                                                      pm25_max = ("pm2.5_atm", "max"),
                                                                                      pm25_min = ("pm2.5_atm", "min"),
                                                                                      pm25_mean = ("pm2.5_atm", "mean"),
                                                                                      pm25_median = ("pm2.5_atm", "median"),

                                                                                      voc_max = ("voc", "max"),
                                                                                      voc_min = ("voc", "min"),
                                                                                      voc_mean = ("voc", "mean"),
                                                                                      voc_median = ("voc", "median"),))
print(stat_summary)
# Out:
#                                                        pm10_max  pm10_min  \
# sensor.name
# #16 - Richardson County Courthouse                  1672.959229  0.840750
# #17 - Otoe County                                     45.739812  0.020000
# #18 - Southeast District Health Department- Tec...  1872.723521  0.205729
# Ainsworth Public School #9                            52.673917  0.172229
# Broken Bow                                          1805.437688  0.089917
# Buffalo County TRPHD #26                              49.871812  0.099562
# ELVPHD Norfolk HD 4                                   95.131583  0.756229
# ELVPHD Tekamah HD 3                                   56.471104  0.513354
# ELVPHD Wisner HD 5                                    60.299813  0.698958
# FCHD-YPS                                             364.240104  0.122643
# Laurel High School                                    48.006125  0.492792
# Loup Basin Public Health Department                  231.757021  0.154146
# Lower Niobrara NRD Butte 10                           52.568208  0.251229
# NCDHD O'Neill #11                                   1763.002868  0.291667
# PHS Fairbury JCHL 13                                  64.502917  0.342687
# SWNPHD-Imerial                                        60.005750  0.012583
# South Heartland District Health Dept. Hastings ...    57.197542  0.186521
# South Heartland District Health Dept. Superior ...    48.692062  0.077333
# Swnphd-Benklemen                                     188.977500  0.039667
# Swnphd-mccook                                       1353.624479  0.169167
# Swnphd-ogallala                                     1321.167583  0.050500
# TRPHD Dawson Co. Courthouse 25                        57.848667  0.182792
# TRPHD Harlan Co. Courthouse 24                        51.376479  0.073750
# Three Rivers Public Health Department                 60.560375  0.697646
# WCDHD Arthur High School 28                           57.954313  0.113458
# WCDHD City Building                                   40.104833  0.156438
# WCDHD Thedford Library 29                             37.635208  0.126104
#
#                                                      pm10_mean  pm10_median  \
# sensor.name
# #16 - Richardson County Courthouse                   39.210342     8.857729
# #17 - Otoe County                                    11.060601     8.997063
# #18 - Southeast District Health Department- Tec...  350.853773     9.147885
# Ainsworth Public School #9                           10.084213     6.918271
# Broken Bow                                          507.306899    16.741738
# Buffalo County TRPHD #26                              9.775754     6.642344
# ELVPHD Norfolk HD 4                                  16.160314    11.474708
# ELVPHD Tekamah HD 3                                  10.671810     7.641479
# ELVPHD Wisner HD 5                                   14.394879    10.187563
# FCHD-YPS                                             11.337509     7.356375
# Laurel High School                                   10.175910     6.720375
# Loup Basin Public Health Department                  10.837193     6.660188
# Lower Niobrara NRD Butte 10                           8.472421     4.717260
# NCDHD O'Neill #11                                   162.777231     8.526312
# PHS Fairbury JCHL 13                                 10.410187     7.777563
# SWNPHD-Imerial                                        7.705157     3.998667
# South Heartland District Health Dept. Hastings ...    9.673907     6.629833
# South Heartland District Health Dept. Superior ...    9.454189     7.554437
# Swnphd-Benklemen                                      9.641012     5.705333
# Swnphd-mccook                                        21.948086     5.220313
# Swnphd-ogallala                                      13.473340     4.248917
# TRPHD Dawson Co. Courthouse 25                       10.409899     6.755998
# TRPHD Harlan Co. Courthouse 24                        8.981578     6.209167
# Three Rivers Public Health Department                10.502022     8.089917
# WCDHD Arthur High School 28                           8.492066     4.942500
# WCDHD City Building                                   4.798076     3.583500
# WCDHD Thedford Library 29                             7.904180     3.935167
#
#                                                        pm25_max  pm25_min  \
# sensor.name
# #16 - Richardson County Courthouse                  1671.833458  0.319292
# #17 - Otoe County                                     37.250062  0.000000
# #18 - Southeast District Health Department- Tec...  1872.126104  0.140708
# Ainsworth Public School #9                            43.320062  0.089375
# Broken Bow                                          1805.313250  0.019187
# Buffalo County TRPHD #26                              42.225333  0.005896
# ELVPHD Norfolk HD 4                                   79.972917  0.307896
# ELVPHD Tekamah HD 3                                   45.881250  0.104938
# ELVPHD Wisner HD 5                                    48.140771  0.154271
# FCHD-YPS                                             363.201104  0.020929
# Laurel High School                                    38.736938  0.080250
# Loup Basin Public Health Department                  230.482438  0.034708
# Lower Niobrara NRD Butte 10                           45.030938  0.082437
# NCDHD O'Neill #11                                   1762.196184  0.136958
# PHS Fairbury JCHL 13                                  52.773958  0.120167
# SWNPHD-Imerial                                        49.004625  0.001313
# South Heartland District Health Dept. Hastings ...    47.330646  0.063292
# South Heartland District Health Dept. Superior ...    40.539417  0.043271
# Swnphd-Benklemen                                     188.156771  0.002500
# Swnphd-mccook                                       1353.337979  0.020000
# Swnphd-ogallala                                     1320.155667  0.014167
# TRPHD Dawson Co. Courthouse 25                        46.411146  0.033188
# TRPHD Harlan Co. Courthouse 24                        42.725625  0.009542
# Three Rivers Public Health Department                 51.491208  0.171833
# WCDHD Arthur High School 28                           46.354292  0.024729
# WCDHD City Building                                   32.589521  0.031354
# WCDHD Thedford Library 29                             31.536167  0.028396
#
#                                                      pm25_mean  pm25_median  \
# sensor.name
# #16 - Richardson County Courthouse                   37.846010     7.730917
# #17 - Otoe County                                     9.311667     7.385583
# #18 - Southeast District Health Department- Tec...  349.785733     7.857365
# Ainsworth Public School #9                            8.868663     6.101708
# Broken Bow                                          506.120734    15.217187
# Buffalo County TRPHD #26                              8.681006     5.732504
# ELVPHD Norfolk HD 4                                  13.521078     9.706229
# ELVPHD Tekamah HD 3                                   9.500374     6.558927
# ELVPHD Wisner HD 5                                   12.111278     8.874458
# FCHD-YPS                                              9.650015     5.692938
# Laurel High School                                    8.522951     5.320062
# Loup Basin Public Health Department                   9.086005     4.963958
# Lower Niobrara NRD Butte 10                           7.557033     3.838281
# NCDHD O'Neill #11                                   161.141576     7.438125
# PHS Fairbury JCHL 13                                  8.981666     6.698125
# SWNPHD-Imerial                                        6.677243     3.416115
# South Heartland District Health Dept. Hastings ...    8.796648     5.993062
# South Heartland District Health Dept. Superior ...    8.564657     6.496250
# Swnphd-Benklemen                                      7.976423     4.279083
# Swnphd-mccook                                        20.778472     4.194417
# Swnphd-ogallala                                      12.450531     3.557562
# TRPHD Dawson Co. Courthouse 25                        9.079663     5.716177
# TRPHD Harlan Co. Courthouse 24                        8.081158     5.329063
# Three Rivers Public Health Department                 9.090555     6.515062
# WCDHD Arthur High School 28                           7.392311     4.401854
# WCDHD City Building                                   3.947973     2.830708
# WCDHD Thedford Library 29                             6.880064     3.500021
#
#                                                         voc_max    voc_min  \
# sensor.name
# #16 - Richardson County Courthouse                   184.185417   0.000000
# #17 - Otoe County                                    730.167333  55.231417
# #18 - Southeast District Health Department- Tec...   636.257917  60.668500
# Ainsworth Public School #9                           670.901292  60.405833
# Broken Bow                                           431.642083   2.561762
# Buffalo County TRPHD #26                             779.814056  50.630500
# ELVPHD Norfolk HD 4                                  884.649000   0.000000
# ELVPHD Tekamah HD 3                                  810.410375  58.165542
# ELVPHD Wisner HD 5                                   432.695042   0.000000
# FCHD-YPS                                             856.012625  54.998000
# Laurel High School                                   372.326000  65.030500
# Loup Basin Public Health Department                  780.413792  61.308542
# Lower Niobrara NRD Butte 10                          626.316125  63.492167
# NCDHD O'Neill #11                                    754.032958  58.984958
# PHS Fairbury JCHL 13                                 700.137208   0.000000
# SWNPHD-Imerial                                      1135.473000  60.117400
# South Heartland District Health Dept. Hastings ...   652.729125  59.692208
# South Heartland District Health Dept. Superior ...   538.228313  61.250208
# Swnphd-Benklemen                                     788.161667  51.998667
# Swnphd-mccook                                        849.734917  59.789667
# Swnphd-ogallala                                     1209.931571  66.296583
# TRPHD Dawson Co. Courthouse 25                       701.490917  63.194167
# TRPHD Harlan Co. Courthouse 24                       554.975333  50.812667
# Three Rivers Public Health Department                741.876042  50.000000
# WCDHD Arthur High School 28                          663.611375  55.925286
# WCDHD City Building                                  612.052292  58.045708
# WCDHD Thedford Library 29                            635.817292  63.229500
#
#                                                       voc_mean  voc_median
# sensor.name
# #16 - Richardson County Courthouse                   86.758650   84.470500
# #17 - Otoe County                                   224.985400  180.043187
# #18 - Southeast District Health Department- Tec...  176.480209  119.176812
# Ainsworth Public School #9                          216.051783  206.472917
# Broken Bow                                          146.894195  129.164167
# Buffalo County TRPHD #26                            329.460463  350.270326
# ELVPHD Norfolk HD 4                                 388.976196  393.061083
# ELVPHD Tekamah HD 3                                 228.178455  157.419062
# ELVPHD Wisner HD 5                                  100.385740  103.363042
# FCHD-YPS                                            387.917269  401.911375
# Laurel High School                                  137.272187  127.579042
# Loup Basin Public Health Department                 392.490499  395.332833
# Lower Niobrara NRD Butte 10                         202.391814  164.658938
# NCDHD O'Neill #11                                   302.572734  297.830458
# PHS Fairbury JCHL 13                                278.282168  291.278375
# SWNPHD-Imerial                                      287.556154  280.883104
# South Heartland District Health Dept. Hastings ...  305.636985  310.016833
# South Heartland District Health Dept. Superior ...  172.478380  151.536833
# Swnphd-Benklemen                                    348.241148  366.150375
# Swnphd-mccook                                       362.835241  396.009000
# Swnphd-ogallala                                     405.802579  442.500500
# TRPHD Dawson Co. Courthouse 25                      312.311781  322.988305
# TRPHD Harlan Co. Courthouse 24                      181.520439  131.013958
# Three Rivers Public Health Department               409.648001  437.144476
# WCDHD Arthur High School 28                         232.874454  201.352542
# WCDHD City Building                                 160.614727   90.996375
# WCDHD Thedford Library 29                           242.884406  214.418208

# %% [markdown]
# ### Lab Activity #4: Put Groups, Filters and Aggregate together
# Try it yourself for this scenario:
# 1. We only want humidity > 20
# 2. We only want alitude > 3000 ft
# 3. We want a summary of max, min, mean, median for `pm10.0_atm`
# 4. We want this data grouped by `monitor_index`

# %%
### Student Response to Lab Activity #4

summary = (
    air_data
    .loc[
        (air_data["humidity"] > 20) &
        (air_data["sensor.altitude"] > 3000)
    ]
    .groupby("monitor_index")
    .agg(
        pm10_max = ("pm10.0_atm", "max"),
        pm10_min = ("pm10.0_atm", "min"),
        pm10_mean = ("pm10.0_atm", "mean"),
        pm10_median = ("pm10.0_atm", "median"),
    ))
print(summary)
# Out:
#                   pm10_max  pm10_min  pm10_mean  pm10_median
# monitor_index
# 194969           60.005750  0.012583   7.347933     3.935271
# 195089          188.977500  0.355208   9.194444     5.659677
# 195355           57.954313  0.113458   7.687824     4.660073
# 195541         1321.167583  0.023250  11.765493     4.388208

# %% [markdown]
# ## Formatting as a Table

# %% [markdown]
# Lastly, let's learn how to create formatted tables that are ordered (ascending or descending) that can be copied and pasted into our reports to our clients.  This is a quick way to combine many of the functions we just learned in a "Pivot Table" (similar to Excel).

# %%
##Create a pivot table!
pm_table = pd.pivot_table(air_data,
                          index="sensor.name",
                          columns=None,
                          values=["pm2.5_atm", "pm10.0_atm"],
                          aggfunc="mean")

# %% [markdown]
# ### Lab Activity 5: Create a Summary Table
# Create a summary Pivot Table that shows data grouped by `sensor.name`, and presents the max and min `pm10.0_atm` value for each location.  Enter your response in the space below.

# %%
### Student Response to Lab Activity #5
pm10_summary = pd.pivot_table(
    air_data,
    index="sensor.name",
    values="pm10.0_atm",
    aggfunc=["min", "max"]
).reset_index()
